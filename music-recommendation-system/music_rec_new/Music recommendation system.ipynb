# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Import Required Libraries

# %% [markdown]
# # Music Recommendation System
#
# This notebook demonstrates a content-based music recommendation system using machine learning. The system analyzes song features (artist, genre, album, rating) to recommend similar songs.
#
# ## Features:
# - Data preprocessing and cleaning
# - Text vectorization using CountVectorizer
# - Cosine similarity for finding similar songs
# - Recommendation engine that suggests top 5 similar songs
#
# ## Libraries Used:
# - **pandas**: Data manipulation and analysis
# - **numpy**: Numerical computing
# - **scikit-learn**: Machine learning algorithms
# - **pickle**: Model serialization
#
# ---

# %%
# Load the music dataset with proper structure
df = pd.read_csv(r"d:\Forked projects\music-recommendation-system-django\music-recommendation-system\music_data.csv")
df
# Out:
#                Song-Name                              Singer/Artists  \
# 0          Proper Patola                              Diljit Dosanjh
# 1           Shape of You                                  Ed Sheeran
# 2              Despacito               Luis Fonsi feat. Daddy Yankee
# 3        Blinding Lights                                  The Weeknd
# 4               Rockstar                 Post Malone feat. 21 Savage
# 5           Dance Monkey                                 Tones and I
# 6      Someone You Loved                               Lewis Capaldi
# 7              Sunflower                      Post Malone & Swae Lee
# 8          Old Town Road             Lil Nas X feat. Billy Ray Cyrus
# 9                Bad Guy                               Billie Eilish
# 10              Senorita               Shawn Mendes & Camila Cabello
# 11               7 rings                               Ariana Grande
# 12            Without Me                                      Halsey
# 13                Sucker                              Jonas Brothers
# 14          I Don't Care                  Ed Sheeran & Justin Bieber
# 15              Memories                                    Maroon 5
# 16               Circles                                 Post Malone
# 17   Lose You To Love Me                                Selena Gomez
# 18      Watermelon Sugar                                Harry Styles
# 19            Levitating                                    Dua Lipa
# 20               Peaches  Justin Bieber feat. Daniel Caesar & Giveon
# 21              Good 4 U                              Olivia Rodrigo
# 22                  Stay               The Kid LAROI & Justin Bieber
# 23         Industry Baby                 Lil Nas X feat. Jack Harlow
# 24            Heat Waves                               Glass Animals
# 25             As It Was                                Harry Styles
# 26       About Damn Time                                       Lizzo
# 27  Running Up That Hill                                   Kate Bush
# 28             Anti-Hero                                Taylor Swift
# 29                Unholy                  Sam Smith feat. Kim Petras
# 30             Calm Down                         Rema & Selena Gomez
# 31               Flowers                                 Miley Cyrus
# 32             Kill Bill                                         SZA
# 33               Creepin       Metro Boomin & The Weeknd & 21 Savage
# 34               Vampire                              Olivia Rodrigo
# 35    Paint The Town Red                                    Doja Cat
# 36          Cruel Summer                                Taylor Swift
# 37  Watermelon Moonshine                                 Chris Young
# 38               Shivers                                  Ed Sheeran
# 39          Stay With Me                                   Sam Smith
# 40               Perfect                                  Ed Sheeran
# 41     Thinking Out Loud                                  Ed Sheeran
# 42            Photograph                                  Ed Sheeran
# 43    Castle on the Hill                                  Ed Sheeran
# 44           Galway Girl                                  Ed Sheeran
# 45               Happier                                  Ed Sheeran
# 46        Nancy Mulligan                                  Ed Sheeran
# 47                Eraser                                  Ed Sheeran
# 48                  Dive                                  Ed Sheeran
# 49               New Man                                  Ed Sheeran
# 50        What Do I Know                                  Ed Sheeran
# 51    How Would You Feel                                  Ed Sheeran
# 52   Supermarket Flowers                                  Ed Sheeran
#
#           Genre                              Album/Movie User-Rating
# 0   Punjabi Pop                          Namaste England       4.5/5
# 1           Pop                                   Divide       4.8/5
# 2     Latin Pop                                     Vida       4.7/5
# 3      Synthpop                              After Hours       4.6/5
# 4       Hip Hop                     Beerbongs & Bentleys       4.4/5
# 5           Pop                      The Kids Are Coming       4.3/5
# 6           Pop  Divinely Uninspired to a Hellish Extent       4.5/5
# 7       Hip Hop        Spider-Man: Into the Spider-Verse       4.6/5
# 8   Country Rap                                     7 EP       4.8/5
# 9    Electropop   When We All Fall Asleep Where Do We Go       4.7/5
# 10    Latin Pop                                  Romance       4.5/5
# 11          Pop                             Thank U Next       4.4/5
# 12          Pop                                    Manic       4.3/5
# 13          Pop                         Happiness Begins       4.2/5
# 14          Pop              No.6 Collaborations Project       4.4/5
# 15          Pop                                    Jordi       4.1/5
# 16          Pop                     Hollywood's Bleeding       4.5/5
# 17          Pop                                     Rare       4.3/5
# 18          Pop                                Fine Line       4.6/5
# 19          Pop                         Future Nostalgia       4.7/5
# 20          R&B                                  Justice       4.4/5
# 21          Pop                                     Sour       4.8/5
# 22          Pop                              F*CK LOVE 3       4.5/5
# 23      Hip Hop                                  Montero       4.6/5
# 24    Indie Pop                                Dreamland       4.4/5
# 25          Pop                            Harry's House       4.7/5
# 26          Pop                                  Special       4.3/5
# 27     Art Rock                           Hounds of Love       4.9/5
# 28          Pop                                Midnights       4.8/5
# 29          Pop                                   Gloria       4.2/5
# 30    Afrobeats                             Rave & Roses       4.5/5
# 31          Pop                  Endless Summer Vacation       4.6/5
# 32          R&B                                      SOS       4.4/5
# 33      Hip Hop                        Heroes & Villains       4.3/5
# 34          Pop                                     Guts       4.7/5
# 35      Hip Hop                                  Scarlet       4.5/5
# 36          Pop                                    Lover       4.8/5
# 37      Country                           Famous Friends       4.2/5
# 38          Pop                                   Equals       4.4/5
# 39         Soul                       In the Lonely Hour       4.6/5
# 40          Pop                                   Divide       4.9/5
# 41          Pop                                        X       4.7/5
# 42          Pop                                        X       4.5/5
# 43          Pop                                   Divide       4.3/5
# 44     Folk Pop                                   Divide       4.4/5
# 45          Pop                                   Divide       4.2/5
# 46         Folk                                   Divide       4.1/5
# 47          Pop                                   Divide       4.0/5
# 48          Pop                                   Divide       4.3/5
# 49          Pop                                   Divide       4.1/5
# 50         Folk                                   Divide       4.2/5
# 51          Pop                                   Divide       4.4/5
# 52       Ballad                                   Divide       4.8/5

# %% [markdown]
# ## 2. Load and Explore Dataset

# %%
df.isnull().sum()
# Out:
# Song-Name         0
# Singer/Artists    0
# Genre             0
# Album/Movie       0
# User-Rating       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## 3. Data Cleaning and Preprocessing

# %%
df.isnull().sum()
# Out:
# Song-Name         0
# Singer/Artists    0
# Genre             0
# Album/Movie       0
# User-Rating       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (53, 5)

# %%
df.head()
# Out:
#          Song-Name                 Singer/Artists        Genre  \
# 0    Proper Patola                 Diljit Dosanjh  Punjabi Pop
# 1     Shape of You                     Ed Sheeran          Pop
# 2        Despacito  Luis Fonsi feat. Daddy Yankee    Latin Pop
# 3  Blinding Lights                     The Weeknd     Synthpop
# 4         Rockstar    Post Malone feat. 21 Savage      Hip Hop
#
#             Album/Movie User-Rating
# 0       Namaste England       4.5/5
# 1                Divide       4.8/5
# 2                  Vida       4.7/5
# 3           After Hours       4.6/5
# 4  Beerbongs & Bentleys       4.4/5

# %%
# Dataset Information
print("Dataset Shape:", df.shape)
print("\nColumn Names:", df.columns.tolist())
print("\nData Types:")
print(df.dtypes)
print("\nBasic Statistics:")
print(df.describe(include='all'))
# Out:
# Dataset Shape: (53, 5)
#
# Column Names: ['Song-Name', 'Singer/Artists', 'Genre', 'Album/Movie', 'User-Rating']
#
# Data Types:
# Song-Name         object
# Singer/Artists    object
# Genre             object
# Album/Movie       object
# User-Rating       object
# dtype: object
#
# Basic Statistics:
#             Song-Name Singer/Artists Genre Album/Movie User-Rating
# count              53             53    53          53          53
# unique             53             36    16          41          10
# top     Proper Patola     Ed Sheeran   Pop      Divide       4.4/5
# freq                1             15    31          12           9

# %%
# Analyze Genre Distribution
print("Genre Distribution:")
print(df['Genre'].value_counts())
print("\nUnique Genres:", df['Genre'].nunique())

print("\n" + "="*50)

# Analyze Artist Distribution  
print("Top 10 Artists:")
print(df['Singer/Artists'].value_counts().head(10))
print("\nUnique Artists:", df['Singer/Artists'].nunique())
# Out:
# Genre Distribution:
# Genre
# Pop            31
# Hip Hop         5
# R&B             2
# Latin Pop       2
# Folk            2
# Synthpop        1
# Country Rap     1
# Punjabi Pop     1
# Electropop      1
# Indie Pop       1
# Afrobeats       1
# Art Rock        1
# Country         1
# Soul            1
# Folk Pop        1
# Ballad          1
# Name: count, dtype: int64
#
# Unique Genres: 16
#
# ==================================================
# Top 10 Artists:
# Singer/Artists
# Ed Sheeran                         15
# Taylor Swift                        2
# Olivia Rodrigo                      2
# Harry Styles                        2
# The Weeknd                          1
# Luis Fonsi feat. Daddy Yankee       1
# Diljit Dosanjh                      1
# Post Malone feat. 21 Savage         1
# Lil Nas X feat. Billy Ray Cyrus     1
# Billie Eilish                       1
# Name: count, dtype: int64
#
# Unique Artists: 36

# %%
df['User-Rating']
# Out:
# 0     4.5/5
# 1     4.8/5
# 2     4.7/5
# 3     4.6/5
# 4     4.4/5
# 5     4.3/5
# 6     4.5/5
# 7     4.6/5
# 8     4.8/5
# 9     4.7/5
# 10    4.5/5
# 11    4.4/5
# 12    4.3/5
# 13    4.2/5
# 14    4.4/5
# 15    4.1/5
# 16    4.5/5
# 17    4.3/5
# 18    4.6/5
# 19    4.7/5
# 20    4.4/5
# 21    4.8/5
# 22    4.5/5
# 23    4.6/5
# 24    4.4/5
# 25    4.7/5
# 26    4.3/5
# 27    4.9/5
# 28    4.8/5
# 29    4.2/5
# 30    4.5/5
# 31    4.6/5
# 32    4.4/5
# 33    4.3/5
# 34    4.7/5
# 35    4.5/5
# 36    4.8/5
# 37    4.2/5
# 38    4.4/5
# 39    4.6/5
# 40    4.9/5
# 41    4.7/5
# 42    4.5/5
# 43    4.3/5
# 44    4.4/5
# 45    4.2/5
# 46    4.1/5
# 47    4.0/5
# 48    4.3/5
# 49    4.1/5
# 50    4.2/5
# 51    4.4/5
# 52    4.8/5
# Name: User-Rating, dtype: object

# %%
l=[]
for i in df['User-Rating']:
    l.append(i[:3])
l
# Out:
# ['4.5',
#  '4.8',
#  '4.7',
#  '4.6',
#  '4.4',
#  '4.3',
#  '4.5',
#  '4.6',
#  '4.8',
#  '4.7',
#  '4.5',
#  '4.4',
#  '4.3',
#  '4.2',
#  '4.4',
#  '4.1',
#  '4.5',
#  '4.3',
#  '4.6',
#  '4.7',
#  '4.4',
#  '4.8',
#  '4.5',
#  '4.6',
#  '4.4',
#  '4.7',
#  '4.3',
#  '4.9',
#  '4.8',
#  '4.2',
#  '4.5',
#  '4.6',
#  '4.4',
#  '4.3',
#  '4.7',
#  '4.5',
#  '4.8',
#  '4.2',
#  '4.4',
#  '4.6',
#  '4.9',
#  '4.7',
#  '4.5',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.1',
#  '4.0',
#  '4.3',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.8']

# %%
# Create an explicit copy to avoid SettingWithCopyWarning
df = df.copy()
df['User-Rating']=l
df
# Out:
#                Song-Name                              Singer/Artists  \
# 0          Proper Patola                              Diljit Dosanjh
# 1           Shape of You                                  Ed Sheeran
# 2              Despacito               Luis Fonsi feat. Daddy Yankee
# 3        Blinding Lights                                  The Weeknd
# 4               Rockstar                 Post Malone feat. 21 Savage
# 5           Dance Monkey                                 Tones and I
# 6      Someone You Loved                               Lewis Capaldi
# 7              Sunflower                      Post Malone & Swae Lee
# 8          Old Town Road             Lil Nas X feat. Billy Ray Cyrus
# 9                Bad Guy                               Billie Eilish
# 10              Senorita               Shawn Mendes & Camila Cabello
# 11               7 rings                               Ariana Grande
# 12            Without Me                                      Halsey
# 13                Sucker                              Jonas Brothers
# 14          I Don't Care                  Ed Sheeran & Justin Bieber
# 15              Memories                                    Maroon 5
# 16               Circles                                 Post Malone
# 17   Lose You To Love Me                                Selena Gomez
# 18      Watermelon Sugar                                Harry Styles
# 19            Levitating                                    Dua Lipa
# 20               Peaches  Justin Bieber feat. Daniel Caesar & Giveon
# 21              Good 4 U                              Olivia Rodrigo
# 22                  Stay               The Kid LAROI & Justin Bieber
# 23         Industry Baby                 Lil Nas X feat. Jack Harlow
# 24            Heat Waves                               Glass Animals
# 25             As It Was                                Harry Styles
# 26       About Damn Time                                       Lizzo
# 27  Running Up That Hill                                   Kate Bush
# 28             Anti-Hero                                Taylor Swift
# 29                Unholy                  Sam Smith feat. Kim Petras
# 30             Calm Down                         Rema & Selena Gomez
# 31               Flowers                                 Miley Cyrus
# 32             Kill Bill                                         SZA
# 33               Creepin       Metro Boomin & The Weeknd & 21 Savage
# 34               Vampire                              Olivia Rodrigo
# 35    Paint The Town Red                                    Doja Cat
# 36          Cruel Summer                                Taylor Swift
# 37  Watermelon Moonshine                                 Chris Young
# 38               Shivers                                  Ed Sheeran
# 39          Stay With Me                                   Sam Smith
# 40               Perfect                                  Ed Sheeran
# 41     Thinking Out Loud                                  Ed Sheeran
# 42            Photograph                                  Ed Sheeran
# 43    Castle on the Hill                                  Ed Sheeran
# 44           Galway Girl                                  Ed Sheeran
# 45               Happier                                  Ed Sheeran
# 46        Nancy Mulligan                                  Ed Sheeran
# 47                Eraser                                  Ed Sheeran
# 48                  Dive                                  Ed Sheeran
# 49               New Man                                  Ed Sheeran
# 50        What Do I Know                                  Ed Sheeran
# 51    How Would You Feel                                  Ed Sheeran
# 52   Supermarket Flowers                                  Ed Sheeran
#
#           Genre                              Album/Movie User-Rating
# 0   Punjabi Pop                          Namaste England         4.5
# 1           Pop                                   Divide         4.8
# 2     Latin Pop                                     Vida         4.7
# 3      Synthpop                              After Hours         4.6
# 4       Hip Hop                     Beerbongs & Bentleys         4.4
# 5           Pop                      The Kids Are Coming         4.3
# 6           Pop  Divinely Uninspired to a Hellish Extent         4.5
# 7       Hip Hop        Spider-Man: Into the Spider-Verse         4.6
# 8   Country Rap                                     7 EP         4.8
# 9    Electropop   When We All Fall Asleep Where Do We Go         4.7
# 10    Latin Pop                                  Romance         4.5
# 11          Pop                             Thank U Next         4.4
# 12          Pop                                    Manic         4.3
# 13          Pop                         Happiness Begins         4.2
# 14          Pop              No.6 Collaborations Project         4.4
# 15          Pop                                    Jordi         4.1
# 16          Pop                     Hollywood's Bleeding         4.5
# 17          Pop                                     Rare         4.3
# 18          Pop                                Fine Line         4.6
# 19          Pop                         Future Nostalgia         4.7
# 20          R&B                                  Justice         4.4
# 21          Pop                                     Sour         4.8
# 22          Pop                              F*CK LOVE 3         4.5
# 23      Hip Hop                                  Montero         4.6
# 24    Indie Pop                                Dreamland         4.4
# 25          Pop                            Harry's House         4.7
# 26          Pop                                  Special         4.3
# 27     Art Rock                           Hounds of Love         4.9
# 28          Pop                                Midnights         4.8
# 29          Pop                                   Gloria         4.2
# 30    Afrobeats                             Rave & Roses         4.5
# 31          Pop                  Endless Summer Vacation         4.6
# 32          R&B                                      SOS         4.4
# 33      Hip Hop                        Heroes & Villains         4.3
# 34          Pop                                     Guts         4.7
# 35      Hip Hop                                  Scarlet         4.5
# 36          Pop                                    Lover         4.8
# 37      Country                           Famous Friends         4.2
# 38          Pop                                   Equals         4.4
# 39         Soul                       In the Lonely Hour         4.6
# 40          Pop                                   Divide         4.9
# 41          Pop                                        X         4.7
# 42          Pop                                        X         4.5
# 43          Pop                                   Divide         4.3
# 44     Folk Pop                                   Divide         4.4
# 45          Pop                                   Divide         4.2
# 46         Folk                                   Divide         4.1
# 47          Pop                                   Divide         4.0
# 48          Pop                                   Divide         4.3
# 49          Pop                                   Divide         4.1
# 50         Folk                                   Divide         4.2
# 51          Pop                                   Divide         4.4
# 52       Ballad                                   Divide         4.8

# %%
# Clean string data - remove spaces and handle missing values
df['Album/Movie'] = df['Album/Movie'].str.replace(' ','')
df['Singer/Artists'] = df['Singer/Artists'].str.replace(' ','')
df
# Out:
#                Song-Name                        Singer/Artists        Genre  \
# 0          Proper Patola                         DiljitDosanjh  Punjabi Pop
# 1           Shape of You                             EdSheeran          Pop
# 2              Despacito             LuisFonsifeat.DaddyYankee    Latin Pop
# 3        Blinding Lights                             TheWeeknd     Synthpop
# 4               Rockstar               PostMalonefeat.21Savage      Hip Hop
# 5           Dance Monkey                             TonesandI          Pop
# 6      Someone You Loved                          LewisCapaldi          Pop
# 7              Sunflower                    PostMalone&SwaeLee      Hip Hop
# 8          Old Town Road             LilNasXfeat.BillyRayCyrus  Country Rap
# 9                Bad Guy                          BillieEilish   Electropop
# 10              Senorita             ShawnMendes&CamilaCabello    Latin Pop
# 11               7 rings                          ArianaGrande          Pop
# 12            Without Me                                Halsey          Pop
# 13                Sucker                         JonasBrothers          Pop
# 14          I Don't Care                EdSheeran&JustinBieber          Pop
# 15              Memories                               Maroon5          Pop
# 16               Circles                            PostMalone          Pop
# 17   Lose You To Love Me                           SelenaGomez          Pop
# 18      Watermelon Sugar                           HarryStyles          Pop
# 19            Levitating                               DuaLipa          Pop
# 20               Peaches  JustinBieberfeat.DanielCaesar&Giveon          R&B
# 21              Good 4 U                         OliviaRodrigo          Pop
# 22                  Stay              TheKidLAROI&JustinBieber          Pop
# 23         Industry Baby                LilNasXfeat.JackHarlow      Hip Hop
# 24            Heat Waves                          GlassAnimals    Indie Pop
# 25             As It Was                           HarryStyles          Pop
# 26       About Damn Time                                 Lizzo          Pop
# 27  Running Up That Hill                              KateBush     Art Rock
# 28             Anti-Hero                           TaylorSwift          Pop
# 29                Unholy                SamSmithfeat.KimPetras          Pop
# 30             Calm Down                      Rema&SelenaGomez    Afrobeats
# 31               Flowers                            MileyCyrus          Pop
# 32             Kill Bill                                   SZA          R&B
# 33               Creepin        MetroBoomin&TheWeeknd&21Savage      Hip Hop
# 34               Vampire                         OliviaRodrigo          Pop
# 35    Paint The Town Red                               DojaCat      Hip Hop
# 36          Cruel Summer                           TaylorSwift          Pop
# 37  Watermelon Moonshine                            ChrisYoung      Country
# 38               Shivers                             EdSheeran          Pop
# 39          Stay With Me                              SamSmith         Soul
# 40               Perfect                             EdSheeran          Pop
# 41     Thinking Out Loud                             EdSheeran          Pop
# 42            Photograph                             EdSheeran          Pop
# 43    Castle on the Hill                             EdSheeran          Pop
# 44           Galway Girl                             EdSheeran     Folk Pop
# 45               Happier                             EdSheeran          Pop
# 46        Nancy Mulligan                             EdSheeran         Folk
# 47                Eraser                             EdSheeran          Pop
# 48                  Dive                             EdSheeran          Pop
# 49               New Man                             EdSheeran          Pop
# 50        What Do I Know                             EdSheeran         Folk
# 51    How Would You Feel                             EdSheeran          Pop
# 52   Supermarket Flowers                             EdSheeran       Ballad
#
#                            Album/Movie User-Rating
# 0                       NamasteEngland         4.5
# 1                               Divide         4.8
# 2                                 Vida         4.7
# 3                           AfterHours         4.6
# 4                   Beerbongs&Bentleys         4.4
# 5                     TheKidsAreComing         4.3
# 6   DivinelyUninspiredtoaHellishExtent         4.5
# 7       Spider-Man:IntotheSpider-Verse         4.6
# 8                                  7EP         4.8
# 9       WhenWeAllFallAsleepWhereDoWeGo         4.7
# 10                             Romance         4.5
# 11                          ThankUNext         4.4
# 12                               Manic         4.3
# 13                     HappinessBegins         4.2
# 14           No.6CollaborationsProject         4.4
# 15                               Jordi         4.1
# 16                 Hollywood'sBleeding         4.5
# 17                                Rare         4.3
# 18                            FineLine         4.6
# 19                     FutureNostalgia         4.7
# 20                             Justice         4.4
# 21                                Sour         4.8
# 22                           F*CKLOVE3         4.5
# 23                             Montero         4.6
# 24                           Dreamland         4.4
# 25                        Harry'sHouse         4.7
# 26                             Special         4.3
# 27                        HoundsofLove         4.9
# 28                           Midnights         4.8
# 29                              Gloria         4.2
# 30                          Rave&Roses         4.5
# 31               EndlessSummerVacation         4.6
# 32                                 SOS         4.4
# 33                     Heroes&Villains         4.3
# 34                                Guts         4.7
# 35                             Scarlet         4.5
# 36                               Lover         4.8
# 37                       FamousFriends         4.2
# 38                              Equals         4.4
# 39                     IntheLonelyHour         4.6
# 40                              Divide         4.9
# 41                                   X         4.7
# 42                                   X         4.5
# 43                              Divide         4.3
# 44                              Divide         4.4
# 45                              Divide         4.2
# 46                              Divide         4.1
# 47                              Divide         4.0
# 48                              Divide         4.3
# 49                              Divide         4.1
# 50                              Divide         4.2
# 51                              Divide         4.4
# 52                              Divide         4.8

# %%
# Replace commas with spaces in Singer/Artists
df['Singer/Artists'] = df['Singer/Artists'].str.replace(',',' ')
df
# Out:
#                Song-Name                        Singer/Artists        Genre  \
# 0          Proper Patola                         DiljitDosanjh  Punjabi Pop
# 1           Shape of You                             EdSheeran          Pop
# 2              Despacito             LuisFonsifeat.DaddyYankee    Latin Pop
# 3        Blinding Lights                             TheWeeknd     Synthpop
# 4               Rockstar               PostMalonefeat.21Savage      Hip Hop
# 5           Dance Monkey                             TonesandI          Pop
# 6      Someone You Loved                          LewisCapaldi          Pop
# 7              Sunflower                    PostMalone&SwaeLee      Hip Hop
# 8          Old Town Road             LilNasXfeat.BillyRayCyrus  Country Rap
# 9                Bad Guy                          BillieEilish   Electropop
# 10              Senorita             ShawnMendes&CamilaCabello    Latin Pop
# 11               7 rings                          ArianaGrande          Pop
# 12            Without Me                                Halsey          Pop
# 13                Sucker                         JonasBrothers          Pop
# 14          I Don't Care                EdSheeran&JustinBieber          Pop
# 15              Memories                               Maroon5          Pop
# 16               Circles                            PostMalone          Pop
# 17   Lose You To Love Me                           SelenaGomez          Pop
# 18      Watermelon Sugar                           HarryStyles          Pop
# 19            Levitating                               DuaLipa          Pop
# 20               Peaches  JustinBieberfeat.DanielCaesar&Giveon          R&B
# 21              Good 4 U                         OliviaRodrigo          Pop
# 22                  Stay              TheKidLAROI&JustinBieber          Pop
# 23         Industry Baby                LilNasXfeat.JackHarlow      Hip Hop
# 24            Heat Waves                          GlassAnimals    Indie Pop
# 25             As It Was                           HarryStyles          Pop
# 26       About Damn Time                                 Lizzo          Pop
# 27  Running Up That Hill                              KateBush     Art Rock
# 28             Anti-Hero                           TaylorSwift          Pop
# 29                Unholy                SamSmithfeat.KimPetras          Pop
# 30             Calm Down                      Rema&SelenaGomez    Afrobeats
# 31               Flowers                            MileyCyrus          Pop
# 32             Kill Bill                                   SZA          R&B
# 33               Creepin        MetroBoomin&TheWeeknd&21Savage      Hip Hop
# 34               Vampire                         OliviaRodrigo          Pop
# 35    Paint The Town Red                               DojaCat      Hip Hop
# 36          Cruel Summer                           TaylorSwift          Pop
# 37  Watermelon Moonshine                            ChrisYoung      Country
# 38               Shivers                             EdSheeran          Pop
# 39          Stay With Me                              SamSmith         Soul
# 40               Perfect                             EdSheeran          Pop
# 41     Thinking Out Loud                             EdSheeran          Pop
# 42            Photograph                             EdSheeran          Pop
# 43    Castle on the Hill                             EdSheeran          Pop
# 44           Galway Girl                             EdSheeran     Folk Pop
# 45               Happier                             EdSheeran          Pop
# 46        Nancy Mulligan                             EdSheeran         Folk
# 47                Eraser                             EdSheeran          Pop
# 48                  Dive                             EdSheeran          Pop
# 49               New Man                             EdSheeran          Pop
# 50        What Do I Know                             EdSheeran         Folk
# 51    How Would You Feel                             EdSheeran          Pop
# 52   Supermarket Flowers                             EdSheeran       Ballad
#
#                            Album/Movie User-Rating
# 0                       NamasteEngland         4.5
# 1                               Divide         4.8
# 2                                 Vida         4.7
# 3                           AfterHours         4.6
# 4                   Beerbongs&Bentleys         4.4
# 5                     TheKidsAreComing         4.3
# 6   DivinelyUninspiredtoaHellishExtent         4.5
# 7       Spider-Man:IntotheSpider-Verse         4.6
# 8                                  7EP         4.8
# 9       WhenWeAllFallAsleepWhereDoWeGo         4.7
# 10                             Romance         4.5
# 11                          ThankUNext         4.4
# 12                               Manic         4.3
# 13                     HappinessBegins         4.2
# 14           No.6CollaborationsProject         4.4
# 15                               Jordi         4.1
# 16                 Hollywood'sBleeding         4.5
# 17                                Rare         4.3
# 18                            FineLine         4.6
# 19                     FutureNostalgia         4.7
# 20                             Justice         4.4
# 21                                Sour         4.8
# 22                           F*CKLOVE3         4.5
# 23                             Montero         4.6
# 24                           Dreamland         4.4
# 25                        Harry'sHouse         4.7
# 26                             Special         4.3
# 27                        HoundsofLove         4.9
# 28                           Midnights         4.8
# 29                              Gloria         4.2
# 30                          Rave&Roses         4.5
# 31               EndlessSummerVacation         4.6
# 32                                 SOS         4.4
# 33                     Heroes&Villains         4.3
# 34                                Guts         4.7
# 35                             Scarlet         4.5
# 36                               Lover         4.8
# 37                       FamousFriends         4.2
# 38                              Equals         4.4
# 39                     IntheLonelyHour         4.6
# 40                              Divide         4.9
# 41                                   X         4.7
# 42                                   X         4.5
# 43                              Divide         4.3
# 44                              Divide         4.4
# 45                              Divide         4.2
# 46                              Divide         4.1
# 47                              Divide         4.0
# 48                              Divide         4.3
# 49                              Divide         4.1
# 50                              Divide         4.2
# 51                              Divide         4.4
# 52                              Divide         4.8

# %%
df['tags']=df['Singer/Artists']+' '+df['Genre']+' '+df['Album/Movie']+' '+df['User-Rating']
df['tags'][0]
# Out:
# 'DiljitDosanjh Punjabi Pop NamasteEngland 4.5'

# %%
# Create new DataFrame with selected columns - use copy() to avoid warnings
new_df = df[['Song-Name','tags']].copy()
new_df
# Out:
#                Song-Name                                               tags
# 0          Proper Patola       DiljitDosanjh Punjabi Pop NamasteEngland 4.5
# 1           Shape of You                           EdSheeran Pop Divide 4.8
# 2              Despacito       LuisFonsifeat.DaddyYankee Latin Pop Vida 4.7
# 3        Blinding Lights                  TheWeeknd Synthpop AfterHours 4.6
# 4               Rockstar  PostMalonefeat.21Savage Hip Hop Beerbongs&Bent...
# 5           Dance Monkey                 TonesandI Pop TheKidsAreComing 4.3
# 6      Someone You Loved  LewisCapaldi Pop DivinelyUninspiredtoaHellishE...
# 7              Sunflower  PostMalone&SwaeLee Hip Hop Spider-Man:IntotheS...
# 8          Old Town Road      LilNasXfeat.BillyRayCyrus Country Rap 7EP 4.8
# 9                Bad Guy  BillieEilish Electropop WhenWeAllFallAsleepWhe...
# 10              Senorita    ShawnMendes&CamilaCabello Latin Pop Romance 4.5
# 11               7 rings                    ArianaGrande Pop ThankUNext 4.4
# 12            Without Me                               Halsey Pop Manic 4.3
# 13                Sucker              JonasBrothers Pop HappinessBegins 4.2
# 14          I Don't Care  EdSheeran&JustinBieber Pop No.6CollaborationsP...
# 15              Memories                              Maroon5 Pop Jordi 4.1
# 16               Circles             PostMalone Pop Hollywood'sBleeding 4.5
# 17   Lose You To Love Me                           SelenaGomez Pop Rare 4.3
# 18      Watermelon Sugar                       HarryStyles Pop FineLine 4.6
# 19            Levitating                    DuaLipa Pop FutureNostalgia 4.7
# 20               Peaches  JustinBieberfeat.DanielCaesar&Giveon R&B Justi...
# 21              Good 4 U                         OliviaRodrigo Pop Sour 4.8
# 22                  Stay         TheKidLAROI&JustinBieber Pop F*CKLOVE3 4.5
# 23         Industry Baby         LilNasXfeat.JackHarlow Hip Hop Montero 4.6
# 24            Heat Waves               GlassAnimals Indie Pop Dreamland 4.4
# 25             As It Was                   HarryStyles Pop Harry'sHouse 4.7
# 26       About Damn Time                              Lizzo Pop Special 4.3
# 27  Running Up That Hill                 KateBush Art Rock HoundsofLove 4.9
# 28             Anti-Hero                      TaylorSwift Pop Midnights 4.8
# 29                Unholy              SamSmithfeat.KimPetras Pop Gloria 4.2
# 30             Calm Down          Rema&SelenaGomez Afrobeats Rave&Roses 4.5
# 31               Flowers           MileyCyrus Pop EndlessSummerVacation 4.6
# 32             Kill Bill                                    SZA R&B SOS 4.4
# 33               Creepin  MetroBoomin&TheWeeknd&21Savage Hip Hop Heroes&...
# 34               Vampire                         OliviaRodrigo Pop Guts 4.7
# 35    Paint The Town Red                        DojaCat Hip Hop Scarlet 4.5
# 36          Cruel Summer                          TaylorSwift Pop Lover 4.8
# 37  Watermelon Moonshine               ChrisYoung Country FamousFriends 4.2
# 38               Shivers                           EdSheeran Pop Equals 4.4
# 39          Stay With Me                  SamSmith Soul IntheLonelyHour 4.6
# 40               Perfect                           EdSheeran Pop Divide 4.9
# 41     Thinking Out Loud                                EdSheeran Pop X 4.7
# 42            Photograph                                EdSheeran Pop X 4.5
# 43    Castle on the Hill                           EdSheeran Pop Divide 4.3
# 44           Galway Girl                      EdSheeran Folk Pop Divide 4.4
# 45               Happier                           EdSheeran Pop Divide 4.2
# 46        Nancy Mulligan                          EdSheeran Folk Divide 4.1
# 47                Eraser                           EdSheeran Pop Divide 4.0
# 48                  Dive                           EdSheeran Pop Divide 4.3
# 49               New Man                           EdSheeran Pop Divide 4.1
# 50        What Do I Know                          EdSheeran Folk Divide 4.2
# 51    How Would You Feel                           EdSheeran Pop Divide 4.4
# 52   Supermarket Flowers                        EdSheeran Ballad Divide 4.8

# %%
# Convert tags to lowercase
new_df['tags'] = new_df['tags'].apply(lambda x: x.lower())
new_df
# Out:
#                Song-Name                                               tags
# 0          Proper Patola       diljitdosanjh punjabi pop namasteengland 4.5
# 1           Shape of You                           edsheeran pop divide 4.8
# 2              Despacito       luisfonsifeat.daddyyankee latin pop vida 4.7
# 3        Blinding Lights                  theweeknd synthpop afterhours 4.6
# 4               Rockstar  postmalonefeat.21savage hip hop beerbongs&bent...
# 5           Dance Monkey                 tonesandi pop thekidsarecoming 4.3
# 6      Someone You Loved  lewiscapaldi pop divinelyuninspiredtoahellishe...
# 7              Sunflower  postmalone&swaelee hip hop spider-man:intothes...
# 8          Old Town Road      lilnasxfeat.billyraycyrus country rap 7ep 4.8
# 9                Bad Guy  billieeilish electropop whenweallfallasleepwhe...
# 10              Senorita    shawnmendes&camilacabello latin pop romance 4.5
# 11               7 rings                    arianagrande pop thankunext 4.4
# 12            Without Me                               halsey pop manic 4.3
# 13                Sucker              jonasbrothers pop happinessbegins 4.2
# 14          I Don't Care  edsheeran&justinbieber pop no.6collaborationsp...
# 15              Memories                              maroon5 pop jordi 4.1
# 16               Circles             postmalone pop hollywood'sbleeding 4.5
# 17   Lose You To Love Me                           selenagomez pop rare 4.3
# 18      Watermelon Sugar                       harrystyles pop fineline 4.6
# 19            Levitating                    dualipa pop futurenostalgia 4.7
# 20               Peaches  justinbieberfeat.danielcaesar&giveon r&b justi...
# 21              Good 4 U                         oliviarodrigo pop sour 4.8
# 22                  Stay         thekidlaroi&justinbieber pop f*cklove3 4.5
# 23         Industry Baby         lilnasxfeat.jackharlow hip hop montero 4.6
# 24            Heat Waves               glassanimals indie pop dreamland 4.4
# 25             As It Was                   harrystyles pop harry'shouse 4.7
# 26       About Damn Time                              lizzo pop special 4.3
# 27  Running Up That Hill                 katebush art rock houndsoflove 4.9
# 28             Anti-Hero                      taylorswift pop midnights 4.8
# 29                Unholy              samsmithfeat.kimpetras pop gloria 4.2
# 30             Calm Down          rema&selenagomez afrobeats rave&roses 4.5
# 31               Flowers           mileycyrus pop endlesssummervacation 4.6
# 32             Kill Bill                                    sza r&b sos 4.4
# 33               Creepin  metroboomin&theweeknd&21savage hip hop heroes&...
# 34               Vampire                         oliviarodrigo pop guts 4.7
# 35    Paint The Town Red                        dojacat hip hop scarlet 4.5
# 36          Cruel Summer                          taylorswift pop lover 4.8
# 37  Watermelon Moonshine               chrisyoung country famousfriends 4.2
# 38               Shivers                           edsheeran pop equals 4.4
# 39          Stay With Me                  samsmith soul inthelonelyhour 4.6
# 40               Perfect                           edsheeran pop divide 4.9
# 41     Thinking Out Loud                                edsheeran pop x 4.7
# 42            Photograph                                edsheeran pop x 4.5
# 43    Castle on the Hill                           edsheeran pop divide 4.3
# 44           Galway Girl                      edsheeran folk pop divide 4.4
# 45               Happier                           edsheeran pop divide 4.2
# 46        Nancy Mulligan                          edsheeran folk divide 4.1
# 47                Eraser                           edsheeran pop divide 4.0
# 48                  Dive                           edsheeran pop divide 4.3
# 49               New Man                           edsheeran pop divide 4.1
# 50        What Do I Know                          edsheeran folk divide 4.2
# 51    How Would You Feel                           edsheeran pop divide 4.4
# 52   Supermarket Flowers                        edsheeran ballad divide 4.8

# %%
# Replace commas with spaces in tags for better text processing
new_df['tags'] = new_df['tags'].str.replace(","," ")
new_df
# Out:
#                Song-Name                                               tags
# 0          Proper Patola       diljitdosanjh punjabi pop namasteengland 4.5
# 1           Shape of You                           edsheeran pop divide 4.8
# 2              Despacito       luisfonsifeat.daddyyankee latin pop vida 4.7
# 3        Blinding Lights                  theweeknd synthpop afterhours 4.6
# 4               Rockstar  postmalonefeat.21savage hip hop beerbongs&bent...
# 5           Dance Monkey                 tonesandi pop thekidsarecoming 4.3
# 6      Someone You Loved  lewiscapaldi pop divinelyuninspiredtoahellishe...
# 7              Sunflower  postmalone&swaelee hip hop spider-man:intothes...
# 8          Old Town Road      lilnasxfeat.billyraycyrus country rap 7ep 4.8
# 9                Bad Guy  billieeilish electropop whenweallfallasleepwhe...
# 10              Senorita    shawnmendes&camilacabello latin pop romance 4.5
# 11               7 rings                    arianagrande pop thankunext 4.4
# 12            Without Me                               halsey pop manic 4.3
# 13                Sucker              jonasbrothers pop happinessbegins 4.2
# 14          I Don't Care  edsheeran&justinbieber pop no.6collaborationsp...
# 15              Memories                              maroon5 pop jordi 4.1
# 16               Circles             postmalone pop hollywood'sbleeding 4.5
# 17   Lose You To Love Me                           selenagomez pop rare 4.3
# 18      Watermelon Sugar                       harrystyles pop fineline 4.6
# 19            Levitating                    dualipa pop futurenostalgia 4.7
# 20               Peaches  justinbieberfeat.danielcaesar&giveon r&b justi...
# 21              Good 4 U                         oliviarodrigo pop sour 4.8
# 22                  Stay         thekidlaroi&justinbieber pop f*cklove3 4.5
# 23         Industry Baby         lilnasxfeat.jackharlow hip hop montero 4.6
# 24            Heat Waves               glassanimals indie pop dreamland 4.4
# 25             As It Was                   harrystyles pop harry'shouse 4.7
# 26       About Damn Time                              lizzo pop special 4.3
# 27  Running Up That Hill                 katebush art rock houndsoflove 4.9
# 28             Anti-Hero                      taylorswift pop midnights 4.8
# 29                Unholy              samsmithfeat.kimpetras pop gloria 4.2
# 30             Calm Down          rema&selenagomez afrobeats rave&roses 4.5
# 31               Flowers           mileycyrus pop endlesssummervacation 4.6
# 32             Kill Bill                                    sza r&b sos 4.4
# 33               Creepin  metroboomin&theweeknd&21savage hip hop heroes&...
# 34               Vampire                         oliviarodrigo pop guts 4.7
# 35    Paint The Town Red                        dojacat hip hop scarlet 4.5
# 36          Cruel Summer                          taylorswift pop lover 4.8
# 37  Watermelon Moonshine               chrisyoung country famousfriends 4.2
# 38               Shivers                           edsheeran pop equals 4.4
# 39          Stay With Me                  samsmith soul inthelonelyhour 4.6
# 40               Perfect                           edsheeran pop divide 4.9
# 41     Thinking Out Loud                                edsheeran pop x 4.7
# 42            Photograph                                edsheeran pop x 4.5
# 43    Castle on the Hill                           edsheeran pop divide 4.3
# 44           Galway Girl                      edsheeran folk pop divide 4.4
# 45               Happier                           edsheeran pop divide 4.2
# 46        Nancy Mulligan                          edsheeran folk divide 4.1
# 47                Eraser                           edsheeran pop divide 4.0
# 48                  Dive                           edsheeran pop divide 4.3
# 49               New Man                           edsheeran pop divide 4.1
# 50        What Do I Know                          edsheeran folk divide 4.2
# 51    How Would You Feel                           edsheeran pop divide 4.4
# 52   Supermarket Flowers                        edsheeran ballad divide 4.8

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2000)

# %% [markdown]
# ## 4. Feature Engineering and Text Vectorization

# %%
vectors=cv.fit_transform(new_df['tags']).toarray()

# %%
vectors.shape
# Out:
# (53, 108)

# %%
# Use get_feature_names_out() instead of deprecated get_feature_names()
cv.get_feature_names_out()
# Out:
# array(['21savage', '6collaborationsproject', '7ep', 'afrobeats',
#        'afterhours', 'arianagrande', 'art', 'ballad', 'beerbongs',
#        'bentleys', 'billieeilish', 'billyraycyrus', 'camilacabello',
#        'chrisyoung', 'cklove3', 'country', 'daddyyankee', 'danielcaesar',
#        'diljitdosanjh', 'divide', 'divinelyuninspiredtoahellishextent',
#        'dojacat', 'dreamland', 'dualipa', 'edsheeran', 'electropop',
#        'endlesssummervacation', 'equals', 'famousfriends', 'fineline',
#        'folk', 'futurenostalgia', 'giveon', 'glassanimals', 'gloria',
#        'guts', 'halsey', 'happinessbegins', 'harry', 'harrystyles',
#        'heroes', 'hip', 'hollywood', 'hop', 'houndsoflove', 'indie',
#        'inthelonelyhour', 'intothespider', 'jackharlow', 'jonasbrothers',
#        'jordi', 'justice', 'justinbieber', 'justinbieberfeat', 'katebush',
#        'kimpetras', 'latin', 'lewiscapaldi', 'lilnasxfeat', 'lizzo',
#        'lover', 'luisfonsifeat', 'man', 'manic', 'maroon5', 'metroboomin',
#        'midnights', 'mileycyrus', 'montero', 'namasteengland', 'no',
#        'oliviarodrigo', 'pop', 'postmalone', 'postmalonefeat', 'punjabi',
#        'rap', 'rare', 'rave', 'rema', 'rock', 'romance', 'roses',
#        'samsmith', 'samsmithfeat', 'sbleeding', 'scarlet', 'selenagomez',
#        'shawnmendes', 'shouse', 'sos', 'soul', 'sour', 'special',
#        'spider', 'swaelee', 'synthpop', 'sza', 'taylorswift',
#        'thankunext', 'thekidlaroi', 'thekidsarecoming', 'theweeknd',
#        'tonesandi', 'verse', 'vida', 'villains',
#        'whenweallfallasleepwheredowego'], dtype=object)

# %%
# Analyze the vectorized features
print("Feature Vector Shape:", vectors.shape)
print("Number of songs:", vectors.shape[0])
print("Number of features:", vectors.shape[1])
print("\nSample of first 20 feature names:")
print(cv.get_feature_names_out()[:20])
# Out:
# Feature Vector Shape: (53, 108)
# Number of songs: 53
# Number of features: 108
#
# Sample of first 20 feature names:
# ['21savage' '6collaborationsproject' '7ep' 'afrobeats' 'afterhours'
#  'arianagrande' 'art' 'ballad' 'beerbongs' 'bentleys' 'billieeilish'
#  'billyraycyrus' 'camilacabello' 'chrisyoung' 'cklove3' 'country'
#  'daddyyankee' 'danielcaesar' 'diljitdosanjh' 'divide']

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)

# %% [markdown]
# ## 5. Calculate Similarity Matrix

# %%
# Analyze the similarity matrix
print("Similarity Matrix Shape:", similarity.shape)
print("Similarity values range from", similarity.min(), "to", similarity.max())
print("\nDiagonal values (self-similarity):", similarity.diagonal()[:5])
print("All diagonal values should be 1.0:", all(similarity.diagonal() == 1.0))
# Out:
# Similarity Matrix Shape: (53, 53)
# Similarity values range from 0.0 to 1.0000000000000002
#
# Diagonal values (self-similarity): [1. 1. 1. 1. 1.]
# All diagonal values should be 1.0: False

# %%
sorted(list(enumerate(similarity[0])),reverse=True,key=lambda x:x[1])
# Out:
# [(0, np.float64(1.0)),
#  (41, np.float64(0.35355339059327373)),
#  (42, np.float64(0.35355339059327373)),
#  (1, np.float64(0.2886751345948129)),
#  (5, np.float64(0.2886751345948129)),
#  (6, np.float64(0.2886751345948129)),
#  (11, np.float64(0.2886751345948129)),
#  (12, np.float64(0.2886751345948129)),
#  (13, np.float64(0.2886751345948129)),
#  (15, np.float64(0.2886751345948129)),
#  (17, np.float64(0.2886751345948129)),
#  (18, np.float64(0.2886751345948129)),
#  (19, np.float64(0.2886751345948129)),
#  (21, np.float64(0.2886751345948129)),
#  (26, np.float64(0.2886751345948129)),
#  (28, np.float64(0.2886751345948129)),
#  (31, np.float64(0.2886751345948129)),
#  (34, np.float64(0.2886751345948129)),
#  (36, np.float64(0.2886751345948129)),
#  (38, np.float64(0.2886751345948129)),
#  (40, np.float64(0.2886751345948129)),
#  (43, np.float64(0.2886751345948129)),
#  (45, np.float64(0.2886751345948129)),
#  (47, np.float64(0.2886751345948129)),
#  (48, np.float64(0.2886751345948129)),
#  (49, np.float64(0.2886751345948129)),
#  (51, np.float64(0.2886751345948129)),
#  (16, np.float64(0.25)),
#  (22, np.float64(0.25)),
#  (24, np.float64(0.25)),
#  (25, np.float64(0.25)),
#  (29, np.float64(0.25)),
#  (44, np.float64(0.25)),
#  (2, np.float64(0.22360679774997896)),
#  (10, np.float64(0.22360679774997896)),
#  (14, np.float64(0.22360679774997896)),
#  (3, np.float64(0.0)),
#  (4, np.float64(0.0)),
#  (7, np.float64(0.0)),
#  (8, np.float64(0.0)),
#  (9, np.float64(0.0)),
#  (20, np.float64(0.0)),
#  (23, np.float64(0.0)),
#  (27, np.float64(0.0)),
#  (30, np.float64(0.0)),
#  (32, np.float64(0.0)),
#  (33, np.float64(0.0)),
#  (35, np.float64(0.0)),
#  (37, np.float64(0.0)),
#  (39, np.float64(0.0)),
#  (46, np.float64(0.0)),
#  (50, np.float64(0.0)),
#  (52, np.float64(0.0))]

# %%
# Rename column - assign back to avoid warnings
new_df = new_df.rename(columns={'Song-Name':'title'})
new_df.head()
# Out:
#              title                                               tags
# 0    Proper Patola       diljitdosanjh punjabi pop namasteengland 4.5
# 1     Shape of You                           edsheeran pop divide 4.8
# 2        Despacito       luisfonsifeat.daddyyankee latin pop vida 4.7
# 3  Blinding Lights                  theweeknd synthpop afterhours 4.6
# 4         Rockstar  postmalonefeat.21savage hip hop beerbongs&bent...

# %%
def recommend(music, num_recommendations=5):
    """
    Recommend similar songs based on the input song
    
    Parameters:
    music (str): The name of the song to get recommendations for
    num_recommendations (int): Number of recommendations to return (default: 5)
    
    Returns:
    list: List of recommended song titles
    """
    try:
        # Find the index of the input song
        music_index = new_df[new_df['title'] == music].index[0]
        
        # Get similarity scores for this song
        distances = similarity[music_index]
        
        # Get sorted list of similar songs (excluding the input song itself)
        music_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:num_recommendations+1]
        
        print(f"🎵 Songs similar to '{music}':")
        print("-" * 50)
        
        recommended_songs = []
        for i, (idx, score) in enumerate(music_list, 1):
            song_title = new_df.iloc[idx].title
            recommended_songs.append(song_title)
            print(f"{i}. {song_title} (Similarity: {score:.3f})")
            
        return recommended_songs
        
    except IndexError:
        print(f"❌ Song '{music}' not found in the dataset.")
        print("Available songs:", new_df['title'].tolist()[:10], "...")
        return []

# %% [markdown]
# ## 6. Build Recommendation System

# %%
recommend('Proper Patola')
# Out:
# 🎵 Songs similar to 'Proper Patola':
# --------------------------------------------------
# 1. Thinking Out Loud (Similarity: 0.354)
# 2. Photograph (Similarity: 0.354)
# 3. Shape of You (Similarity: 0.289)
# 4. Dance Monkey (Similarity: 0.289)
# 5. Someone You Loved (Similarity: 0.289)
# ['Thinking Out Loud',
#  'Photograph',
#  'Shape of You',
#  'Dance Monkey',
#  'Someone You Loved']

# %%
# Test with different songs and genres
test_songs = ['Shape of You', 'Blinding Lights', 'Heat Waves']

for song in test_songs:
    print(f"\n{'='*60}")
    recommend(song)
    print()
# Out:
# ============================================================
# 🎵 Songs similar to 'Shape of You':
# --------------------------------------------------
# 1. Perfect (Similarity: 1.000)
# 2. Castle on the Hill (Similarity: 1.000)
# 3. Happier (Similarity: 1.000)
# 4. Eraser (Similarity: 1.000)
# 5. Dive (Similarity: 1.000)
#
#
# ============================================================
# 🎵 Songs similar to 'Blinding Lights':
# --------------------------------------------------
# 1. Creepin (Similarity: 0.218)
# 2. Proper Patola (Similarity: 0.000)
# 3. Shape of You (Similarity: 0.000)
# 4. Despacito (Similarity: 0.000)
# 5. Rockstar (Similarity: 0.000)
#
#
# ============================================================
# 🎵 Songs similar to 'Heat Waves':
# --------------------------------------------------
# 1. Thinking Out Loud (Similarity: 0.354)
# 2. Photograph (Similarity: 0.354)
# 3. Shape of You (Similarity: 0.289)
# 4. Dance Monkey (Similarity: 0.289)
# 5. Someone You Loved (Similarity: 0.289)

# %%
# Evaluation: Check genre consistency in recommendations
def evaluate_recommendations(song_name, original_df):
    """Evaluate if recommendations maintain genre consistency"""
    try:
        # Get original song's genre
        original_genre = original_df[original_df['Song-Name'] == song_name]['Genre'].iloc[0]
        
        # Get recommendations
        recommendations = recommend(song_name, num_recommendations=5)
        
        if not recommendations:
            return
            
        # Check genre consistency
        print(f"\n📊 Genre Analysis for '{song_name}' (Original: {original_genre}):")
        print("-" * 60)
        
        genre_matches = 0
        for rec_song in recommendations:
            rec_genre = original_df[original_df['Song-Name'] == rec_song]['Genre'].iloc[0]
            match = "✅" if original_genre.split()[0] in rec_genre or rec_genre.split()[0] in original_genre else "❌"
            print(f"{match} {rec_song} - {rec_genre}")
            if match == "✅":
                genre_matches += 1
                
        accuracy = (genre_matches / len(recommendations)) * 100
        print(f"\n🎯 Genre Consistency: {accuracy:.1f}% ({genre_matches}/{len(recommendations)})")
        
    except Exception as e:
        print(f"Error in evaluation: {e}")

# Test evaluation
evaluate_recommendations('Shape of You', df)
# Out:
# 🎵 Songs similar to 'Shape of You':
# --------------------------------------------------
# 1. Perfect (Similarity: 1.000)
# 2. Castle on the Hill (Similarity: 1.000)
# 3. Happier (Similarity: 1.000)
# 4. Eraser (Similarity: 1.000)
# 5. Dive (Similarity: 1.000)
#
# 📊 Genre Analysis for 'Shape of You' (Original: Pop):
# ------------------------------------------------------------
# ✅ Perfect - Pop
# ✅ Castle on the Hill - Pop
# ✅ Happier - Pop
# ✅ Eraser - Pop
# ✅ Dive - Pop
#
# 🎯 Genre Consistency: 100.0% (5/5)

# %% [markdown]
# ## 7. Test Recommendations

# %%
df.head(50)
# Out:
#                Song-Name                        Singer/Artists        Genre  \
# 0          Proper Patola                         DiljitDosanjh  Punjabi Pop
# 1           Shape of You                             EdSheeran          Pop
# 2              Despacito             LuisFonsifeat.DaddyYankee    Latin Pop
# 3        Blinding Lights                             TheWeeknd     Synthpop
# 4               Rockstar               PostMalonefeat.21Savage      Hip Hop
# 5           Dance Monkey                             TonesandI          Pop
# 6      Someone You Loved                          LewisCapaldi          Pop
# 7              Sunflower                    PostMalone&SwaeLee      Hip Hop
# 8          Old Town Road             LilNasXfeat.BillyRayCyrus  Country Rap
# 9                Bad Guy                          BillieEilish   Electropop
# 10              Senorita             ShawnMendes&CamilaCabello    Latin Pop
# 11               7 rings                          ArianaGrande          Pop
# 12            Without Me                                Halsey          Pop
# 13                Sucker                         JonasBrothers          Pop
# 14          I Don't Care                EdSheeran&JustinBieber          Pop
# 15              Memories                               Maroon5          Pop
# 16               Circles                            PostMalone          Pop
# 17   Lose You To Love Me                           SelenaGomez          Pop
# 18      Watermelon Sugar                           HarryStyles          Pop
# 19            Levitating                               DuaLipa          Pop
# 20               Peaches  JustinBieberfeat.DanielCaesar&Giveon          R&B
# 21              Good 4 U                         OliviaRodrigo          Pop
# 22                  Stay              TheKidLAROI&JustinBieber          Pop
# 23         Industry Baby                LilNasXfeat.JackHarlow      Hip Hop
# 24            Heat Waves                          GlassAnimals    Indie Pop
# 25             As It Was                           HarryStyles          Pop
# 26       About Damn Time                                 Lizzo          Pop
# 27  Running Up That Hill                              KateBush     Art Rock
# 28             Anti-Hero                           TaylorSwift          Pop
# 29                Unholy                SamSmithfeat.KimPetras          Pop
# 30             Calm Down                      Rema&SelenaGomez    Afrobeats
# 31               Flowers                            MileyCyrus          Pop
# 32             Kill Bill                                   SZA          R&B
# 33               Creepin        MetroBoomin&TheWeeknd&21Savage      Hip Hop
# 34               Vampire                         OliviaRodrigo          Pop
# 35    Paint The Town Red                               DojaCat      Hip Hop
# 36          Cruel Summer                           TaylorSwift          Pop
# 37  Watermelon Moonshine                            ChrisYoung      Country
# 38               Shivers                             EdSheeran          Pop
# 39          Stay With Me                              SamSmith         Soul
# 40               Perfect                             EdSheeran          Pop
# 41     Thinking Out Loud                             EdSheeran          Pop
# 42            Photograph                             EdSheeran          Pop
# 43    Castle on the Hill                             EdSheeran          Pop
# 44           Galway Girl                             EdSheeran     Folk Pop
# 45               Happier                             EdSheeran          Pop
# 46        Nancy Mulligan                             EdSheeran         Folk
# 47                Eraser                             EdSheeran          Pop
# 48                  Dive                             EdSheeran          Pop
# 49               New Man                             EdSheeran          Pop
#
#                            Album/Movie User-Rating  \
# 0                       NamasteEngland         4.5
# 1                               Divide         4.8
# 2                                 Vida         4.7
# 3                           AfterHours         4.6
# 4                   Beerbongs&Bentleys         4.4
# 5                     TheKidsAreComing         4.3
# 6   DivinelyUninspiredtoaHellishExtent         4.5
# 7       Spider-Man:IntotheSpider-Verse         4.6
# 8                                  7EP         4.8
# 9       WhenWeAllFallAsleepWhereDoWeGo         4.7
# 10                             Romance         4.5
# 11                          ThankUNext         4.4
# 12                               Manic         4.3
# 13                     HappinessBegins         4.2
# 14           No.6CollaborationsProject         4.4
# 15                               Jordi         4.1
# 16                 Hollywood'sBleeding         4.5
# 17                                Rare         4.3
# 18                            FineLine         4.6
# 19                     FutureNostalgia         4.7
# 20                             Justice         4.4
# 21                                Sour         4.8
# 22                           F*CKLOVE3         4.5
# 23                             Montero         4.6
# 24                           Dreamland         4.4
# 25                        Harry'sHouse         4.7
# 26                             Special         4.3
# 27                        HoundsofLove         4.9
# 28                           Midnights         4.8
# 29                              Gloria         4.2
# 30                          Rave&Roses         4.5
# 31               EndlessSummerVacation         4.6
# 32                                 SOS         4.4
# 33                     Heroes&Villains         4.3
# 34                                Guts         4.7
# 35                             Scarlet         4.5
# 36                               Lover         4.8
# 37                       FamousFriends         4.2
# 38                              Equals         4.4
# 39                     IntheLonelyHour         4.6
# 40                              Divide         4.9
# 41                                   X         4.7
# 42                                   X         4.5
# 43                              Divide         4.3
# 44                              Divide         4.4
# 45                              Divide         4.2
# 46                              Divide         4.1
# 47                              Divide         4.0
# 48                              Divide         4.3
# 49                              Divide         4.1
#
#                                                  tags
# 0        DiljitDosanjh Punjabi Pop NamasteEngland 4.5
# 1                            EdSheeran Pop Divide 4.8
# 2        LuisFonsifeat.DaddyYankee Latin Pop Vida 4.7
# 3                   TheWeeknd Synthpop AfterHours 4.6
# 4   PostMalonefeat.21Savage Hip Hop Beerbongs&Bent...
# 5                  TonesandI Pop TheKidsAreComing 4.3
# 6   LewisCapaldi Pop DivinelyUninspiredtoaHellishE...
# 7   PostMalone&SwaeLee Hip Hop Spider-Man:IntotheS...
# 8       LilNasXfeat.BillyRayCyrus Country Rap 7EP 4.8
# 9   BillieEilish Electropop WhenWeAllFallAsleepWhe...
# 10    ShawnMendes&CamilaCabello Latin Pop Romance 4.5
# 11                    ArianaGrande Pop ThankUNext 4.4
# 12                               Halsey Pop Manic 4.3
# 13              JonasBrothers Pop HappinessBegins 4.2
# 14  EdSheeran&JustinBieber Pop No.6CollaborationsP...
# 15                              Maroon5 Pop Jordi 4.1
# 16             PostMalone Pop Hollywood'sBleeding 4.5
# 17                           SelenaGomez Pop Rare 4.3
# 18                       HarryStyles Pop FineLine 4.6
# 19                    DuaLipa Pop FutureNostalgia 4.7
# 20  JustinBieberfeat.DanielCaesar&Giveon R&B Justi...
# 21                         OliviaRodrigo Pop Sour 4.8
# 22         TheKidLAROI&JustinBieber Pop F*CKLOVE3 4.5
# 23         LilNasXfeat.JackHarlow Hip Hop Montero 4.6
# 24               GlassAnimals Indie Pop Dreamland 4.4
# 25                   HarryStyles Pop Harry'sHouse 4.7
# 26                              Lizzo Pop Special 4.3
# 27                 KateBush Art Rock HoundsofLove 4.9
# 28                      TaylorSwift Pop Midnights 4.8
# 29              SamSmithfeat.KimPetras Pop Gloria 4.2
# 30          Rema&SelenaGomez Afrobeats Rave&Roses 4.5
# 31           MileyCyrus Pop EndlessSummerVacation 4.6
# 32                                    SZA R&B SOS 4.4
# 33  MetroBoomin&TheWeeknd&21Savage Hip Hop Heroes&...
# 34                         OliviaRodrigo Pop Guts 4.7
# 35                        DojaCat Hip Hop Scarlet 4.5
# 36                          TaylorSwift Pop Lover 4.8
# 37               ChrisYoung Country FamousFriends 4.2
# 38                           EdSheeran Pop Equals 4.4
# 39                  SamSmith Soul IntheLonelyHour 4.6
# 40                           EdSheeran Pop Divide 4.9
# 41                                EdSheeran Pop X 4.7
# 42                                EdSheeran Pop X 4.5
# 43                           EdSheeran Pop Divide 4.3
# 44                      EdSheeran Folk Pop Divide 4.4
# 45                           EdSheeran Pop Divide 4.2
# 46                          EdSheeran Folk Divide 4.1
# 47                           EdSheeran Pop Divide 4.0
# 48                           EdSheeran Pop Divide 4.3
# 49                           EdSheeran Pop Divide 4.1

# %%
# Save the processed dataset and similarity matrix for production use
import pickle
import os

try:
    # Save the processed music dataframe
    pickle.dump(new_df, open('musicrec.pkl', 'wb'))
    print("✅ Successfully saved music dataframe to 'musicrec.pkl'")
    
    # Check file size
    file_size = os.path.getsize('musicrec.pkl') / 1024  # KB
    print(f"📁 File size: {file_size:.2f} KB")
    
except Exception as e:
    print(f"❌ Error saving music dataframe: {e}")
# Out:
# ✅ Successfully saved music dataframe to 'musicrec.pkl'
# 📁 File size: 3.22 KB

# %% [markdown]
# ## 8. Save Model for Production Use

# %%
try:
    # Save the similarity matrix
    pickle.dump(similarity, open('similarities.pkl', 'wb'))
    print("✅ Successfully saved similarity matrix to 'similarities.pkl'")
    
    # Check file size
    file_size = os.path.getsize('similarities.pkl') / 1024  # KB
    print(f"📁 File size: {file_size:.2f} KB")
    
    print(f"\n🎯 Model files ready for Django integration!")
    print("Files created:")
    print("- musicrec.pkl (music dataframe)")
    print("- similarities.pkl (similarity matrix)")
    
except Exception as e:
    print(f"❌ Error saving similarity matrix: {e}")
# Out:
# ✅ Successfully saved similarity matrix to 'similarities.pkl'
# 📁 File size: 22.09 KB
#
# 🎯 Model files ready for Django integration!
# Files created:
# - musicrec.pkl (music dataframe)
# - similarities.pkl (similarity matrix)

# %% [markdown]
# ## 9. Summary and Next Steps
#
# ### What We Built:
# ✅ **Content-based recommendation system** using song features
# ✅ **Text vectorization** with CountVectorizer (2000 features max)
# ✅ **Cosine similarity** for finding similar songs
# ✅ **Error handling** and evaluation metrics
# ✅ **Model persistence** for production deployment
#
# ### Key Results:
# - Successfully processes music metadata (artist, genre, album, rating)
# - Generates relevant recommendations based on content similarity
# - Maintains genre consistency in recommendations
# - Ready for integration with Django web application
#
# ### Possible Improvements:
# 1. **Add more features**: Release year, tempo, mood, language
# 2. **Hybrid approach**: Combine content-based with collaborative filtering
# 3. **Deep learning**: Use embeddings for better similarity computation
# 4. **Real-time updates**: Handle new songs and user feedback
# 5. **A/B testing**: Compare different recommendation algorithms
#
# ### Integration with Django:
# The saved pickle files (`musicrec.pkl` and `similarities.pkl`) can be loaded in the Django application for real-time recommendations.
